# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Amazon.csv')

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200

# %%
df = df.drop(columns = ['Adj Close'])

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083  18853200

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.plot(df['Date'], df['Close'], color = 'blue')
ax.xaxis.set_major_locator(plt.MaxNLocator(14))
ax.set_xlabel('Date', fontsize = '12')
ax.set_ylabel('Price in USD', fontsize = '12')
plt.title("Amazon Stock Price")
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(df['Date'], df['Close'], color = 'blue')
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
ax.set_xlabel('Date', fontsize = '12')
ax.set_ylabel('Price in USD', fontsize = '12')
plt.title("Amazon Stock Price")
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(df['Date'], df['Volume'], color = 'blue')
ax.xaxis.set_major_locator(plt.MaxNLocator(14))
ax.set_xlabel('Date', fontsize = '12')
ax.set_ylabel('Price in USD', fontsize = '12')
plt.title("Amazon Stock Price")
plt.grid()
plt.show()

# %%
df['Market Cap'] = df['Open']*df['Volume']

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close    Volume    Market Cap
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333  72156000  1.758802e+08
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167  14700000  2.894062e+07
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   6106800  1.075051e+07
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   5467200  9.453702e+06
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083  18853200  3.083284e+07

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.plot(df['Date'], df['Market Cap'], color = 'red')
ax.xaxis.set_major_locator(plt.MaxNLocator(18))
ax.set_xlabel('Date', fontsize = '12')
ax.set_ylabel('Price in USD', fontsize = '12')
plt.title("Amazon Stock Price")
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(df['Date'], df['Market Cap'], color = 'purple')
ax.xaxis.set_major_locator(plt.MaxNLocator(18))
ax.set_xlabel('Date', fontsize = '12')
ax.set_ylabel('Price in USD', fontsize = '12')
plt.title("Amazon Stock Price")
plt.grid()
plt.show()

# %%
df.iloc[df['Market Cap'].argmax()]
# Out:
# Date                2021-07-30
# Open               3347.949951
# High               3368.139893
# Low                 3306.97998
# Close              3327.590088
# Volume                 9957100
# Market Cap    33335872457.1021
# Name: 6092, dtype: object

# %%
ohlc = df[df['Date'] > '1997-05-15']

# %%
ohlc
# Out:
#             Date         Open         High          Low        Close  \
# 1     1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2     1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3     1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4     1997-05-21     1.635417     1.645833     1.375000     1.427083
# 5     1997-05-22     1.437500     1.447917     1.312500     1.395833
# ...          ...          ...          ...          ...          ...
# 6150  2021-10-21  3414.250000  3440.280029  3403.000000  3435.010010
# 6151  2021-10-22  3421.000000  3429.840088  3331.300049  3335.550049
# 6152  2021-10-25  3335.000000  3347.800049  3297.699951  3320.370117
# 6153  2021-10-26  3349.510010  3416.120117  3343.979980  3376.070068
# 6154  2021-10-27  3388.000000  3412.000000  3371.453369  3396.189941
#
#         Volume    Market Cap
# 1     14700000  2.894062e+07
# 2      6106800  1.075051e+07
# 3      5467200  9.453702e+06
# 4     18853200  3.083284e+07
# 5     11776800  1.692915e+07
# ...        ...           ...
# 6150   1881400  6.423570e+09
# 6151   3133800  1.072073e+10
# 6152   2226000  7.423710e+09
# 6153   2693700  9.022575e+09
# 6154   1080291  3.660026e+09
#
# [6154 rows x 7 columns]

# %%
ohlc = ohlc.loc[:,['Date','Open','High', 'Low', 'Close','Volume', 'Market Cap']]

# %%
ohlc.head()
# Out:
#          Date      Open      High       Low     Close    Volume    Market Cap
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167  14700000  2.894062e+07
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   6106800  1.075051e+07
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   5467200  9.453702e+06
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083  18853200  3.083284e+07
# 5  1997-05-22  1.437500  1.447917  1.312500  1.395833  11776800  1.692915e+07

# %%
# ohlc['Date'] = pd.to_datetime(ohlc['Date'], format='%d-%m-%Y')

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.plot(ohlc['Date'], ohlc['Market Cap'], color = 'orange')
ax.xaxis.set_major_locator(plt.MaxNLocator(5))
ax.set_ylabel('Market Cap', fontsize =  '11')
plt.grid()
plt.show()

# %%
df['Vol'] = (df['Close']/df['Close'].shift(1)) - 1

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close    Volume    Market Cap  \
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333  72156000  1.758802e+08
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167  14700000  2.894062e+07
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   6106800  1.075051e+07
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   5467200  9.453702e+06
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083  18853200  3.083284e+07
#
#         Vol
# 0       NaN
# 1 -0.117021
# 2 -0.012049
# 3 -0.042683
# 4 -0.127389

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.plot(df['Date'], df['Vol'], color = 'r')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
plt.title('Volatility')
plt.grid()
plt.show()

# %%
df['Vol'].hist(bins = 50, color = '#20C841')
# Out:
# <AxesSubplot: >

# %%
df['Cumulative Return'] = (1 + df['Vol']).cumprod()
fig, ax = plt.subplots(figsize=(20,8))
ax.bar(df['Date'], df['Cumulative Return'], color='#147202')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize='11')
ax.set_ylabel('Cumulative Return', fontsize='11')
plt.title('Cumulative Return')
plt.grid()
plt.show()

# %%
df.iloc[df['Cumulative Return'].argmax()]
# Out:
# Date                         2021-07-08
# Open                        3643.560059
# High                         3759.98999
# Low                         3621.120117
# Close                       3731.409912
# Volume                          5180600
# Market Cap           18875827241.655399
# Vol                            0.009422
# Cumulative Return            1905.40113
# Name: 6076, dtype: object

# %% [markdown]
# # Using Machine and Deep learning Model

# %%
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import math

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df.head()
# Out:
#                 Open      High       Low     Close    Volume    Market Cap  \
# Date
# 1997-05-15  2.437500  2.500000  1.927083  1.958333  72156000  1.758802e+08
# 1997-05-16  1.968750  1.979167  1.708333  1.729167  14700000  2.894062e+07
# 1997-05-19  1.760417  1.770833  1.625000  1.708333   6106800  1.075051e+07
# 1997-05-20  1.729167  1.750000  1.635417  1.635417   5467200  9.453702e+06
# 1997-05-21  1.635417  1.645833  1.375000  1.427083  18853200  3.083284e+07
#
#                  Vol  Cumulative Return
# Date
# 1997-05-15       NaN                NaN
# 1997-05-16 -0.117021           0.882979
# 1997-05-19 -0.012049           0.872340
# 1997-05-20 -0.042683           0.835107
# 1997-05-21 -0.127389           0.728723

# %%
data = df.filter(['Close'])
data.head()
# Out:
#                Close
# Date
# 1997-05-15  1.958333
# 1997-05-16  1.729167
# 1997-05-19  1.708333
# 1997-05-20  1.635417
# 1997-05-21  1.427083

# %%
dataset = data.values
training_data_len = math.ceil(len(dataset)*0.8)
training_data_len
# Out:
# 4924

# %% [markdown]
# #### Data Scaler

# %%
scaler = MinMaxScaler(feature_range = (0,1))

# %%
dataset
# Out:
# array([[1.95833300e+00],
#        [1.72916700e+00],
#        [1.70833300e+00],
#        ...,
#        [3.32037012e+03],
#        [3.37607007e+03],
#        [3.39618994e+03]])

# %%
scaler
# Out:
# MinMaxScaler()

# %%
scaled_data = scaler.fit_transform(dataset)

# %%
scaled_data
# Out:
# array([[1.50803720e-04],
#        [8.93653463e-05],
#        [8.37798446e-05],
#        ...,
#        [8.89802079e-01],
#        [9.04734986e-01],
#        [9.10129033e-01]])

# %%
train_data = scaled_data[0:training_data_len, :]

# %%
train_data
# Out:
# array([[1.50803720e-04],
#        [8.93653463e-05],
#        [8.37798446e-05],
#        ...,
#        [1.98107615e-01],
#        [2.03206780e-01],
#        [2.04643769e-01]])

# %%
train_data.shape
# Out:
# (4924, 1)

# %%
x_train = []
y_train = []
for i in range(60,len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i,0])
    if i<= 60:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([1.50803720e-04, 8.93653463e-05, 8.37798446e-05, 6.42313929e-05,
#        8.37798446e-06, 0.00000000e+00, 2.79267042e-05, 5.02679068e-05,
#        3.63046887e-05, 2.93229456e-05, 2.79267042e-05, 3.07194551e-05,
#        2.23414706e-05, 5.58550171e-06, 3.90974396e-05, 6.98166266e-05,
#        7.81946110e-05, 5.02679068e-05, 3.90974396e-05, 5.58534085e-05,
#        5.02679068e-05, 4.74754240e-05, 2.93229456e-05, 3.07194551e-05,
#        3.07194551e-05, 3.49084473e-05, 2.79267042e-05, 3.07194551e-05,
#        3.07194551e-05, 3.07194551e-05, 2.51339534e-05, 3.90974396e-05,
#        3.21156965e-05, 5.16644163e-05, 1.38236744e-04, 1.61974456e-04,
#        2.42961549e-04, 2.48547051e-04, 3.12778176e-04, 2.40169067e-04,
#        1.98279144e-04, 2.79266238e-04, 2.51339534e-04, 2.20620347e-04,
#        2.03864378e-04, 2.10846121e-04, 1.98279144e-04, 2.40169067e-04,
#        2.31791082e-04, 2.23413098e-04, 2.48547051e-04, 2.90436973e-04,
#        2.82058989e-04, 2.68095503e-04, 2.73681005e-04, 2.45754300e-04,
#        2.17827596e-04, 2.28998331e-04, 2.09449612e-04, 2.40169067e-04])]
# [0.00024994329250626934]

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))

# %%
x_train.shape
# Out:
# (4864, 60, 1)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences = False))
model.add(Dense(32))
model.add(Dense(1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(x_train,y_train, batch_size = 1, epochs = 10)
# Out:
# Epoch 1/10
# 4864/4864 [==============================] - 37s 7ms/step - loss: 4.3603e-05
# Epoch 2/10
# 4864/4864 [==============================] - 37s 8ms/step - loss: 1.4506e-05
# Epoch 3/10
# 4864/4864 [==============================] - 35s 7ms/step - loss: 1.3613e-05
# Epoch 4/10
# 4864/4864 [==============================] - 35s 7ms/step - loss: 8.6059e-06
# Epoch 5/10
# 4864/4864 [==============================] - 35s 7ms/step - loss: 7.9685e-06
# Epoch 6/10
# 4864/4864 [==============================] - 35s 7ms/step - loss: 6.9933e-06
# Epoch 7/10
# 4864/4864 [==============================] - 35s 7ms/step - loss: 6.4576e-06
# Epoch 8/10
# 4864/4864 [==============================] - 36s 7ms/step - loss: 6.7381e-06
# Epoch 9/10
# 4864/4864 [==============================] - 35s 7ms/step - loss: 7.1714e-06
# Epoch 10/10
# 4864/4864 [==============================] - 35s 7ms/step - loss: 5.4069e-06

# %%
test_data = scaled_data[training_data_len-60:, :]
x_test = []
y_test = dataset[training_data_len:,:]
for i in range(60,len(test_data)):
    x_test.append(test_data[i-60:i,0])

# %%
x_test = np.array(x_test)

# %%
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1],1))
x_test.shape
# Out:
# (1231, 60, 1)

# %%
Prediction = model.predict(x_test)
# Out:
# 39/39 [==============================] - 1s 6ms/step

# %%
Prediction = scaler.inverse_transform(Prediction)

# %%
Prediction
# Out:
# array([[ 734.3188 ],
#        [ 739.5115 ],
#        [ 735.57263],
#        ...,
#        [3064.6257 ],
#        [3062.8179 ],
#        [3123.1938 ]], dtype=float32)

# %%
RMSE = np.sqrt(np.mean(Prediction - y_test)**2)
RMSE
# Out:
# 132.13279240493628

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = Prediction
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price' ,fontsize=18)
plt.plot(train['Close'],linewidth=3.5)
plt.plot(valid[['Close','Predictions']],linewidth=3.5)
plt.legend(['Train','Valid','Predictions'], loc='upper left')
plt.show()
# Out:
# C:\Users\Ziyed hossen\AppData\Local\Temp\ipykernel_10644\1024673033.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = Prediction

# %%
valid
# Out:
#                   Close  Predictions
# Date
# 2016-12-07   770.419983   734.318787
# 2016-12-08   767.330017   739.511475
# 2016-12-09   768.659973   735.572632
# 2016-12-12   760.119995   737.143127
# 2016-12-13   774.340027   728.109680
# ...                 ...          ...
# 2021-10-21  3435.010010  3143.442627
# 2021-10-22  3335.550049  3168.210449
# 2021-10-25  3320.370117  3064.625732
# 2021-10-26  3376.070068  3062.817871
# 2021-10-27  3396.189941  3123.193848
#
# [1231 rows x 2 columns]
